# %%
from google.colab import files
da = files.upload()
from google.colab import drive
drive.mount('/content/drive')
# Out:
#      <input type="file" id="files-09d07cc6-c92f-458e-b15a-f10e6ade2c65" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-09d07cc6-c92f-458e-b15a-f10e6ade2c65">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# %%
df = pd.read_csv('/content/drive/MyDrive/Sample_hotel_data.csv')
df.head(2)
# Out:
#        Hotel_Name_City  Review_Overall_Rating date_of_review Month_of_Visit  \
# 0  Bombay Hotel Jaipur                      3      8/26/2014         Aug-14
# 1  Bombay Hotel Jaipur                      1     06-02-2013         Jun-13
#
#    Review_Type  Rating_Value  Rating_Location  Rating_Sleep_Quality  \
# 0  with family           3.0              4.0                   NaN
# 1          NaN           1.0              2.0                   NaN
#
#    Rating_Rooms  Rating_Cleanliness  Rating_Service
# 0           NaN                 NaN             3.0
# 1           1.0                 1.0             3.0

# %%
pip install sweetviz
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.1/15.1 MB 66.3 MB/s eta 0:00:00
# ...

# %%
import sweetviz as sv
hotelsfeedback_report = sv.analyze(df)
hotelsfeedback_report.show_html('Analyst.html')
# Out:
#                                              |          | [  0%]   00:00 -> (? left)
# Report Analyst.html was generated! NOTEBOOK/COLAB USERS: the web browser MAY not pop up, regardless, the report IS saved in your notebook/colab files.

# %% [markdown]
# 1)Analyze
# To analyze a single dataframe, simply use the analyze(...) function, then the show_html(...) function:

# %% [markdown]
# 2)Compare
# Sweetviz can also be used to visualize the comparison of test and train data.Now i'm gonna Comparing two dataframes (e.g. Test vs Training sets).So for Comparing i'm gonna use the Iris Flower Dat

# %%
iris = pd.read_csv('/content/drive/MyDrive/DM-Assignment-2-part2/iris.data.csv')
iris.head(2)
# Out:
#    5.1  3.5  1.4  0.2  Iris-setosa
# 0  4.9  3.0  1.4  0.2  Iris-setosa
# 1  4.7  3.2  1.3  0.2  Iris-setosa

# %%
train = iris[:70]
test = iris[70:]
comparison_report = sv.compare(train,test)
comparison_report.show_html('Comparison.html')
# Out:
#                                              |          | [  0%]   00:00 -> (? left)
# Report Comparison.html was generated! NOTEBOOK/COLAB USERS: the web browser MAY not pop up, regardless, the report IS saved in your notebook/colab files.

# %% [markdown]
# 3)compare
# Now if you want to compare the analysis between two subpopulations then you can use compare_intra() function from the sweetviz library. Support for this is built in through the compare_intra() function. This function takes a boolean series as one of the arguments, as well as an explicit "name" tuple for naming the (true, false) resulting datasets. Note that internally, this creates 2 separate dataframes to represent each resulting group. As such, it is more of a shorthand function of doing such processing manually

# %%
IFrame(src = 'Comparison.html',width=1000,height=500)

# %%
IFrame(src = 'internal_column.html',width=1000,height=500)

# %%
import sweetviz as sv
hotelsfeedback_report = sv.analyze(df)
hotelsfeedback_report.show_html('Analyst.html')
